# %% [markdown]
# # Audio Analysis – Preprocessing Assignment
#
# **Submitted by:** Goutham G
# **Date:** 27th November 2025
#
# ## Objective
# Automatic Podcast Transcription and Topic Segmentation
#
# This notebook demonstrates standard audio preprocessing steps used before feeding data to ASR and NLP pipelines.

# %% [markdown]
# ## 1. Installing & Importing Libraries

# %%
# %pip install librosa noisereduce soundfile webrtcvad numpy matplotlib
# Out:
# Requirement already satisfied: librosa in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (0.11.0)
# Requirement already satisfied: noisereduce in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (3.0.3)
# Requirement already satisfied: soundfile in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (0.13.1)
# Collecting webrtcvad
#   Using cached webrtcvad-2.0.10.tar.gz (66 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (3.10.6)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from librosa) (0.63.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.7.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\gouth\appdata\roaming\python\python311\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: tqdm in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from noisereduce) (4.67.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0->soundfile) (2.23)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from numba>=0.51.0->librosa) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\gouth\appdata\roaming\python\python311\site-packages (from pooch>=1.1->librosa) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.8.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: colorama in c:\users\gouth\appdata\local\programs\python\python311\lib\site-packages (from tqdm->noisereduce) (0.4.6)
# Building wheels for collected packages: webrtcvad
#   Building wheel for webrtcvad (pyproject.toml): started
#   Building wheel for webrtcvad (pyproject.toml): finished with status 'error'
# Failed to build webrtcvad
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for webrtcvad (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [23 lines of output]
#       C:\Users\gouth\AppData\Local\Temp\pip-build-env-bq2cgfg0\overlay\Lib\site-packages\setuptools\_distutils\dist.py:289: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       C:\Users\gouth\AppData\Local\Temp\pip-build-env-bq2cgfg0\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-311
#       copying webrtcvad.py -> build\lib.win-amd64-cpython-311
#       running build_ext
#       building '_webrtcvad' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for webrtcvad
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> webrtcvad

# %%
import librosa
import numpy as np
import soundfile as sf
import noisereduce as nr
import matplotlib.pyplot as plt
import webrtcvad
import os

# %% [markdown]
# ## 2. Load & Inspect Audio File

# %%
audio_path = "..\dataset\Harward mini OR\OSR_us_000_0010_8k.wav"

y, sr = librosa.load(audio_path, sr=None)
print(f"Sample Rate: {sr}")
print(f"Duration: {len(y)/sr:.2f} seconds")
# Out:
# Sample Rate: 8000
# Duration: 33.62 seconds

# %% [markdown]
# ## 3. Resample Audio to 16 kHz

# %%
target_sr = 16000
if sr != target_sr:
    y = librosa.resample(y, orig_sr=sr, target_sr=target_sr)
    sr = target_sr

# %% [markdown]
# ## 4. Convert Stereo to Mono

# %%
y = librosa.to_mono(y)

# %% [markdown]
# ## 5. Amplitude Normalization

# %%
y = y / np.max(np.abs(y))

# %% [markdown]
# ## 6. Noise Reduction

# %%
y_denoised = nr.reduce_noise(y=y, sr=sr)

# %% [markdown]
# ## 7. Silence Removal

# %%
intervals = librosa.effects.split(y_denoised, top_db=20)
y_nonsilent = np.concatenate([y_denoised[start:end] for start, end in intervals])

# %% [markdown]
# ## 8. Voice Activity Detection (VAD)
# Using WebRTC VAD for detecting speech segments.

# %%
vad = webrtcvad.Vad(2)

def frame_generator(frame_duration_ms, audio, sample_rate):
    frame_length = int(sample_rate * frame_duration_ms / 1000)
    for i in range(0, len(audio), frame_length):
        yield audio[i:i + frame_length]

speech_frames = []
for frame in frame_generator(30, (y_nonsilent * 32768).astype(np.int16), sr):
    if len(frame) == int(sr * 0.03):
        if vad.is_speech(frame.tobytes(), sr):
            speech_frames.append(frame)

speech_audio = np.concatenate(speech_frames) if speech_frames else np.array([])

# %% [markdown]
# ## 9. Save Preprocessed Audio

# %%
sf.write("processed_audio.wav", speech_audio, sr)
print("Preprocessing complete. File saved as processed_audio.wav")
# Out:
# Preprocessing complete. File saved as processed_audio.wav

# %% [markdown]
# ## Final Output
# This preprocessed audio can now be directly used for:
# - Automatic Speech Recognition (ASR)
# - Topic Segmentation
# - Speaker Diarization
